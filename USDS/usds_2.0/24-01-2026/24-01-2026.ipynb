# %% [markdown]
# # Non-Primitive Data Types

# %% [markdown]
# ### List

# %%
l = ["Hello", "Hey", "Python", 10, False]

# %%
print(l[3])
# Out:
# 10

# %%
print(l[0])
# Out:
# Hello

# %%
print(l[-1])
# Out:
# False

# %%
print(l[-2])
# Out:
# 10

# %%
# len()

# %%
len("Data")
# Out:
# 4

# %%
len(l)
# Out:
# 5

# %%
# len(l) --> 5
l[len(l)-1] # (5-1) -> 4 --> l[4] --> False
# Out:
# False

# %%
l[-1]
# Out:
# False

# %%
l[-6]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 l[-6]
#
# IndexError: list index out of range

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10, False]

# %%
# pop()

l.pop() # bydefault behaviour is top remove last element
# Out:
# False

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10]

# %%
l.append(True)

# %%
l
# Out:
# ['Hello', 'Hey', 'Python', 10, True]

# %%
l.pop(0)
# Out:
# 'Hello'

# %%
l
# Out:
# ['Hey', 'Python', 10, True]

# %%
l.append('Hey')

# %%
l
# Out:
# ['Python', 10, 'Machine learning', True]

# %%
l[0] = "Python-v2.0"

# %%
l
# Out:
# ['Python-v2.0', 10, 'Machine learning', True]

# %%
# what to do when we dont know the index of element we want 
# to remove but we know the value we want to remove

# we will use remove

l.remove('Hey')

# %%
l
# Out:
# ['Python', 10, True, 'Hey']

# %%
l.remove('Hey')

# %%
l
# Out:
# ['Python', 10, True]

# %%
l.insert(2, "Machine learning")

# %%
l
# Out:
# ['Python', 10, 'Machine learning', True]

# %% [markdown]
# ### Dictionary

# %%
# {key : value}

register = {
    "Rohit" : ["12-12-1980", 123456789, "abcdefgh"],
    "Rohith" : ["12-12-1980", 123456789, "abcd"],
    "monal" : False
}

# %%
print(register)
# Out:
# {'Rohit': ['12-12-1980', 123456789, 'abcdefgh'], 'Rohith': ['12-12-1980', 123456789, 'abcd'], 'monal': False}

# %%
goverment_sys = {
    101 : ["Monal"],
    102 : ["Amit"],
    103 : ["Dhaval"],
    104 : ["Surya"]
}

# %%
goverment_sys.get(101)
# Out:
# ['Monal']

# %%
goverment_sys.get(110, "Value not present")
# Out:
# 'Value not present'

# %%
goverment_sys[101]
# Out:
# ['Monal']

# %%
goverment_sys[105]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[48], line 1
# ----> 1 goverment_sys[105]
#
# KeyError: 105

# %%
goverment_sys.keys()
print(list(goverment_sys.keys()))
# Out:
# [101, 102, 103, 104]

# %%
goverment_sys.values()
print(list(goverment_sys.values()))
# Out:
# [['Monal'], ['Amit'], ['Dhaval'], ['Surya']]

# %%
for i in list(goverment_sys.keys()):
    print(i)
# Out:
# 101
# 102
# 103
# 104

# %%
for i in list(goverment_sys.values()):
    print(i)
# Out:
# ['Monal']
# ['Amit']
# ['Dhaval']
# ['Surya']

# %%
a = {
    [1,2,3] : "hello"
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 a = {
#       2     [1,2,3] : "hello"
#       3 }
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# ### Tuple

# %%
empty_tuple = ()

# %%
print(empty_tuple)
# Out:
# ()

# %%
empty_tuple = tuple()
print(type(empty_tuple))
# Out:
# <class 'tuple'>

# %%
print(type(empty_tuple))
# Out:
# <class 'tuple'>

# %%
dob = (10, "Feb", 1920)

# %%
print(type(dob))
# Out:
# <class 'tuple'>

# %%
dob
# Out:
# (10, 'Feb', 1920)

# %%
dob[0]
# Out:
# 10

# %%
dob[0] = 20
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[70], line 1
# ----> 1 dob[0] = 20
#
# TypeError: 'tuple' object does not support item assignment

# %%
register_v2 = {
    101 : {
        "Name" : "Monal",
        "DOB" : (10, "feb", 1920),
        "Phone.no" : "+91-1111111111"
    },
    102 : {
        "Name" : "Ashish",
        "DOB" : (10, "feb", 1990),
        "Phone.no" : "+91-1111111111"
    }
}

# int, float, string, boolean
# list, dict, tuple

# %%
register_v2[101]
# Out:
# {'Name': 'Monal', 'DOB': (10, 'feb', 1920), 'Phone.no': '+91-1111111111'}

# %%
register_v3 = {
    101 : {
            "Name" : {
                "First_name" : "Monal",
                "Last_name" : "S"
            },
            "DOB" : (10, "feb", 1920),
            "Phone.no" : "+91-1111111111"
        }
}

# %%
register_v3[101]["DOB"]
# Out:
# (10, 'feb', 1920)

# %%
type(register_v3[101]["DOB"])
# Out:
# tuple

# %%
get_101_dob = register_v3[101]["DOB"]

# %%
get_101_dob
# Out:
# (10, 'feb', 1920)

# %%
register_v3.get(101).get('DOB')

# traversal
# Out:
# (10, 'feb', 1920)

# %%
register_v3.get(101)['DOB']
# traversal
# Out:
# (10, 'feb', 1920)

# %%
register_v3.get(101)['DOB'][0] = 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 register_v3.get(101)['DOB'][0] = 10
#
# TypeError: 'tuple' object does not support item assignment

# %%
register_v3.get(101).get('DOB')[0]
# Out:
# 10

# %% [markdown]
# ### SET

# %%
guests = set()

# %%
guests
# Out:
# set()

# %%
guests = {"Alice", "Alice", "Tanmay", 123, 1001, 123, "Sudarshan"}

# %%
print(guests)
# Out:
# {'Tanmay', 'Sudarshan', 'Alice', 1001, 123}

# %%
alpha = {"a", "b", "d", "z", "g"}

# %%
print(alpha)
# Out:
# {'b', 'a', 'd', 'g', 'z'}

# %%
a = list()
b = []
print(type(a), type(b))
# Out:
# <class 'list'> <class 'list'>

# %%
# how to add elements to a set()
print(guests)
guests.add(10)
print(guests)
# Out:
# {'Tanmay', 'Sudarshan', 'Alice', 1001, 123}
# {'Tanmay', 'Sudarshan', 'Alice', 1001, 10, 123}

# %%
alpha = {"a", "b", "d", "z", "g"}

# %%
print(type(alpha))
# Out:
# <class 'set'>

# %%
# use function sorted to sort elements

alpha = sorted(alpha)

# %%
print(alpha)
# Out:
# ['a', 'b', 'd', 'g', 'z']

# %%
alpha_reverse = sorted(alpha, reverse=True)
print(alpha_reverse)
# Out:
# ['z', 'g', 'd', 'b', 'a']

# %%
sorted([1,2,3,100,2])
# Out:
# [1, 2, 2, 3, 100]

# %%
# Out:
# [1, 2, 2, 3, 100]
